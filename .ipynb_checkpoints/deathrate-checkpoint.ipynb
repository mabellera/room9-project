# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Reading data file
filepath = "data/VA_OutcomesMeasures_October2016_CMS_Submission.xlsx"

# %%
# Getting info from death rate sheet
main_dr_df = pd.read_excel(filepath, sheet_name="Death Rates")
main_dr_df.dropna()
main_dr_df.head()
# Out:
#      CCN#                                       VHA Facility  \
# 0  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 1  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 2  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 3  01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 4  01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
#
#                  Address        City State  Zip\nCode                Measure  \
# 0  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0  VA 30-day Death Rates
# 1  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0  VA 30-day Death Rates
# 2  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0  VA 30-day Death Rates
# 3    215 PERRY HILL ROAD  MONTGOMERY    AL    36109.0  VA 30-day Death Rates
# 4    215 PERRY HILL ROAD  MONTGOMERY    AL    36109.0  VA 30-day Death Rates
#
#                       Disease Cohort  Rate 95% Confidence Lower Limit  \
# ...

# %%
# Extract just Georgia and Virginia information from main data frame
va_ga_dr_df = main_dr_df[(main_dr_df["State"]== 'VA') |    (main_dr_df["State"]== 'GA')]

# Replace values that have "*" with "NaN" so that we can then use .dropna to get rid of the rows with missing information
va_ga_dr_df['Rate']= va_ga_dr_df['Rate'].replace({"*": np.nan})
va_ga_dr_df['95% Confidence Lower Limit']= va_ga_dr_df['95% Confidence Lower Limit'].replace({"*": np.nan})
va_ga_dr_df['95% Confidence Upper Limit']= va_ga_dr_df['95% Confidence Upper Limit'].replace({"*": np.nan})

# Delete columns with unnecessary information
del va_ga_dr_df["Footnotes"]
del va_ga_dr_df["Date Range"]

# Dropna 
va_ga_dr_df = va_ga_dr_df.dropna()

# Rename columns to remove \n typo
va_ga_dr_df = va_ga_dr_df.rename(columns={"Zip\nCode": "Zip Code",
                           "VHA\n National Rate": "VHA National Rate",
                           "Number of\n Observations": "Number Observations",
                           "Number of\n Deaths": "Number Deaths"})

# Print df
va_ga_dr_df.head()
# Out:
# <ipython-input-3-d5b912f7c874>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va_ga_dr_df['Rate']= va_ga_dr_df['Rate'].replace({"*": np.nan})
# <ipython-input-3-d5b912f7c874>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   va_ga_dr_df['95% Confidence Lower Limit']= va_ga_dr_df['95% Confidence Lower Limit'].replace({"*": np.nan})
# <ipython-input-3-d5b912f7c874>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Creating a data frame for georgia information
ga_dr_df = va_ga_dr_df[va_ga_dr_df["State"]=="GA"]

# Print df
ga_dr_df
# Out:
#       CCN#                         VHA Facility                  Address  \
# 78  11029F  DECATUR (ATLANTA) VA MEDICAL CENTER      1670 CLAIRMONT ROAD
# 79  11029F  DECATUR (ATLANTA) VA MEDICAL CENTER      1670 CLAIRMONT ROAD
# 80  11029F  DECATUR (ATLANTA) VA MEDICAL CENTER      1670 CLAIRMONT ROAD
# 81  11030F            AUGUSTA VA MEDICAL CENTER          950 15TH STREET
# 82  11030F            AUGUSTA VA MEDICAL CENTER          950 15TH STREET
# 83  11030F            AUGUSTA VA MEDICAL CENTER          950 15TH STREET
# 85  11031F             DUBLIN VA MEDICAL CENTER  1826 VETERANS BOULEVARD
# 86  11031F             DUBLIN VA MEDICAL CENTER  1826 VETERANS BOULEVARD
#
#        City State  Zip Code                Measure  \
# 78  DECATUR    GA   30033.0  VA 30-day Death Rates
# 79  DECATUR    GA   30033.0  VA 30-day Death Rates
# 80  DECATUR    GA   30033.0  VA 30-day Death Rates
# 81  AUGUSTA    GA   30901.0  VA 30-day Death Rates
# ...

# %%
# Finding and storing the average national death rate
VHA_National_Rate_mean = ga_dr_df.loc[ga_dr_df["CCN#"] == "11029F", :]["VHA National Rate"].mean()
VHA_National_Rate_mean
# Out:
# 8.523333333333333

# %%
# Creating lits for data frame to include National Death rate alongside facility death rates
summary_df_index = ga_grouped_hos['Rate'].mean().index.tolist()
summary_df_index.append("VHA National Rate")
summary_df_rates = ga_grouped_hos['Rate'].mean().tolist()
summary_df_rates.append(VHA_National_Rate_mean)
summary_df = pd.DataFrame({"Facility": summary_df_index, "Rates": summary_df_rates})
summary_df
# Out:
#                               Facility     Rates
# 0            AUGUSTA VA MEDICAL CENTER  8.676667
# 1  DECATUR (ATLANTA) VA MEDICAL CENTER  7.263333
# 2             DUBLIN VA MEDICAL CENTER  8.050000
# 3                    VHA National Rate  8.523333

# %%
# Creating vizualization for Georgia Hospitals
plt.barh(summary_df["Facility"], summary_df["Rates"], color=["magenta", "cyan", "orange", "limegreen"])

# Cleaning format
plt.ylabel("VHA Facility")
plt.xlabel("Death Rate Average (%)")
plt.title("Death Rate Average (%) per VHA Facilities in Georgia")
# Out:
# Text(0.5, 1.0, 'Death Rate Average (%) per VHA Facilities in Georgia')

# %%
# # Group by Hospital
# ga_grouped_hos = ga_dr_df.groupby(['VHA Facility'])
# ga_grouped_hos.head()

# # Creating vizualization for Georgia Hospitals
# x_axis = np.arange(len(ga_grouped_hos['VHA Facility']))
# plt.bar(x_axis, ga_grouped_hos['Rate'].mean(), color=["magenta", "cyan", "orange"])

# # Cleaning bar chart format
# tick_locations = x_axis
# plt.xticks(np.arange(3), ['Augusta VA Medical Center', 'Atlanta VA Medical Center', 'Dublin VA Medical Center'], rotation=60)
# plt.ylabel("Death Rate Average (%)")
# plt.xlabel("VHA Facility")
# plt.title("Death Rate Average (%) per VHA Facilities in Georgia")

# %%
# Creating another vizualization
x_axis = np.arange(len(ga_grouped_hos['VHA Facility']))
plt.bar(x_axis, ga_grouped_hos['Number Deaths'].sum(), color=["magenta", "cyan", "orange"])

# Cleaning bar chart format
tick_locations = x_axis
plt.xticks(np.arange(3), ['Augusta VA Medical Center', 'Atlanta VA Medical Center', 'Dublin VA Medical Center'], rotation=60)
plt.ylabel("Total Number of Deaths")
plt.xlabel("VHA Facility")
plt.title("Total Number of Deaths per VHA Facilities in Georgia")
# Out:
# Text(0.5, 1.0, 'Total Number of Deaths per VHA Facilities in Georgia')

# %%
# Creating a data frame for virginia information
va_dr_df = va_ga_dr_df[va_ga_dr_df["State"]=="VA"]

# Print df
va_dr_df.head()
# Out:
#        CCN#                VHA Facility                    Address      City  \
# 343  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 344  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 345  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
# 346  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
# 347  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
#
#     State  Zip Code                Measure                     Disease Cohort  \
# 343    VA   23667.0  VA 30-day Death Rates     Congestive Heart Failure (CHF)
# 344    VA   23667.0  VA 30-day Death Rates                     Pneumonia (PN)
# 345    VA   23249.0  VA 30-day Death Rates  Acute Myocardial Infarction (AMI)
# 346    VA   23249.0  VA 30-day Death Rates     Congestive Heart Failure (CHF)
# 347    VA   23249.0  VA 30-day Death Rates                     Pneumonia (PN)
#
# ...

# %%
# Finding and storing the national death rate 
VHA_National_Rate_mean_va = va_dr_df.loc[va_dr_df["CCN#"] == "49010F", :]["VHA National Rate"].mean()
VHA_National_Rate_mean_va
# Out:
# 8.523333333333333

# %%
# Creating lits for data frame to include National Death rate alongside facility death rates
summary_df_index_va = va_grouped_hos['Rate'].mean().index.tolist()
summary_df_index_va.append("VHA National Rate")
summary_df_rates_va = va_grouped_hos['Rate'].mean().tolist()
summary_df_rates_va.append(VHA_National_Rate_mean_va)
summary_df_va = pd.DataFrame({"Facility": summary_df_index_va, "Rates": summary_df_rates_va})
summary_df_va
# Out:
#                      Facility     Rates
# 0   HAMPTON VA MEDICAL CENTER  8.285000
# 1  RICHMOND VA MEDICAL CENTER  8.793333
# 2     SALEM VA MEDICAL CENTER  8.663333
# 3           VHA National Rate  8.523333

# %%
# Creating vizualization for Virginia Hospitals
plt.barh(summary_df_va["Facility"], summary_df_va["Rates"], color=["magenta", "cyan", "orange", "limegreen"])

# Cleaning format
plt.ylabel("VHA Facility")
plt.xlabel("Death Rate Average (%)")
plt.title("Death Rate Average (%) per VHA Facilities in Virginia")
# Out:
# Text(0.5, 1.0, 'Death Rate Average (%) per VHA Facilities in Virginia')

# %%
# # Group by Hospital
# va_grouped_hos = va_dr_df.groupby(['VHA Facility'])
# va_grouped_hos.head()

# # Creating vizualization for Georgia Hospitals
# x_axis = np.arange(len(va_grouped_hos['VHA Facility']))
# plt.bar(x_axis, va_grouped_hos['Rate'].mean(), color=["magenta", "cyan", "orange"])

# # Cleaning bar chart format
# tick_locations = x_axis
# plt.xticks(np.arange(3), ['Richmond VA Medical Center', 'Salem VA Medical Center', 'Hampton VA Medical Center'], rotation=60)
# plt.ylabel("Death Rate Average (%)")
# plt.xlabel("VHA Facility")
# plt.title("Death Rate Average (%) per VHA Facilities in Virginia")

# %%
# Creating another vizualization
x_axis = np.arange(len(va_grouped_hos['VHA Facility']))
plt.bar(x_axis, va_grouped_hos['Number Deaths'].sum(), color=["magenta", "cyan", "orange"])

# Cleaning bar chart format
tick_locations = x_axis
plt.xticks(np.arange(3), ['Richmond VA Medical Center', 'Salem VA Medical Center', 'Hampton VA Medical Center'], rotation=60)
plt.ylabel("Total Number of Deaths")
plt.xlabel("VHA Facility")
plt.title("Total Number of Deaths per VHA Facilities in Virginia")
# Out:
# Text(0.5, 1.0, 'Total Number of Deaths per VHA Facilities in Virginia')
