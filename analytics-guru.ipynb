# %%
# import the dependencies
# Load file 
# create the main dataframes
# check if need any cleanup
# Pick one Measure/indicator to compare between hostipals in georgia 
# Pick one Measure/indicator to compare  between hostipals in VA 
# Pick one Measure to compare between hostipals in georgia and VA
# crete the visualization 
# now repeat.

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# filename: # VA_OutcomesMeasures_October2016_CMS_Submission
filepath = "data/VA_OutcomesMeasures_October2016_CMS_Submission.xlsx"

main_psi_df = pd.read_excel(filepath, sheet_name="PSI")
main_psi_df.head()
# Out:
#   CCN# VHA Facility Address City State  Zip\nCode  \
# 0  NaN  VA National     NaN  NaN   NaN        NaN
# 1  NaN  VA National     NaN  NaN   NaN        NaN
# 2  NaN  VA National     NaN  NaN   NaN        NaN
# 3  NaN  VA National     NaN  NaN   NaN        NaN
# 4  NaN  VA National     NaN  NaN   NaN        NaN
#
#                            Measure                             Indicator  \
# 0  Patient Safety Indicators (PSI)                   03 - Pressure Ulcer
# 1  Patient Safety Indicators (PSI)  04 - Death Among Surgical Inpatients
# 2  Patient Safety Indicators (PSI)          06 - Iatrogenic Pneumothorax
# 3  Patient Safety Indicators (PSI)                  07 - CLAB Infections
# 4  Patient Safety Indicators (PSI)              08 - Postop Hip Fracture
#
#   Observed Rate Expected Rate Risk Adjusted Rate 95% Confidence Lower Limit  \
# 0          0.35          0.51               0.35                       0.28
# 1        105.38        120.78             104.27                      97.42
# 2           0.3          0.31               0.33                        0.3
# 3          0.14          0.27               0.11                       0.08
# 4          0.06          0.05               0.06                       0.03
#
#   95% Confidence Upper Limit Footnotes                     Date Range
# 0                       0.42       NaN  October 2012 – September 2015
# 1                     111.11       NaN  October 2012 – September 2015
# 2                       0.36       NaN  October 2012 – September 2015
# 3                       0.14       NaN  October 2012 – September 2015
# 4                       0.08       NaN  October 2012 – September 2015

# %%
main_dr_df = pd.read_excel(filepath, sheet_name="Death Rates")
main_dr_df.head()
# Out:
#      CCN#                                       VHA Facility  \
# 0  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 1  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 2  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 3  01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 4  01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
#
#                  Address        City State  Zip\nCode                Measure  \
# 0  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0  VA 30-day Death Rates
# 1  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0  VA 30-day Death Rates
# 2  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0  VA 30-day Death Rates
# 3    215 PERRY HILL ROAD  MONTGOMERY    AL    36109.0  VA 30-day Death Rates
# 4    215 PERRY HILL ROAD  MONTGOMERY    AL    36109.0  VA 30-day Death Rates
#
#                       Disease Cohort  Rate 95% Confidence Lower Limit  \
# 0  Acute Myocardial Infarction (AMI)  9.68                       7.35
# 1     Congestive Heart Failure (CHF)  6.89                       5.17
# 2                     Pneumonia (PN)  9.17                       7.01
# 3  Acute Myocardial Infarction (AMI)     *                          *
# 4     Congestive Heart Failure (CHF)  7.15                       4.81
#
#   95% Confidence Upper Limit  VHA\n National Rate Number of\n Observations  \
# 0                      12.84                 9.21                      134
# 1                        9.3                 7.72                      389
# 2                      11.98                 8.64                      148
# 3                          *                 9.21                        8
# 4                      10.38                 7.72                       85
#
#   Number of\n Deaths                                       Footnotes  \
# 0                 14                                             NaN
# 1                 25                                             NaN
# 2                 16                                             NaN
# 3                  1  * Rates are not reported for Observations < 25
# 4                  4                                             NaN
#
#                       Date Range
# 0  October 2013 – September 2015
# 1  October 2013 – September 2015
# 2  October 2013 – September 2015
# 3  October 2013 – September 2015
# 4  October 2013 – September 2015

# %%
main_rr_df = pd.read_excel(filepath, sheet_name="Readmission Rate")
main_rr_df.head()
# Out:
#      CCN#                                       VHA Facility  \
# 0  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 1  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 2  01014F                       BIRMINGHAM VA MEDICAL CENTER
# 3  01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
# 4  01019F  VA CENTRAL ALABAMA HEALTHCARE SYSTEM - MONTGOMERY
#
#                  Address        City State  Zip\nCode  \
# 0  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0
# 1  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0
# 2  700 SOUTH 19TH STREET  BIRMINGHAM    AL    35233.0
# 3    215 PERRY HILL ROAD  MONTGOMERY    AL    36109.0
# 4    215 PERRY HILL ROAD  MONTGOMERY    AL    36109.0
#
#                        Measure                     Disease Cohort   Rate  \
# 0  VA 30-day Readmission Rates  Acute Myocardial Infarction (AMI)  15.17
# 1  VA 30-day Readmission Rates     Congestive Heart Failure (CHF)  20.67
# 2  VA 30-day Readmission Rates                     Pneumonia (PN)  15.73
# 3  VA 30-day Readmission Rates  Acute Myocardial Infarction (AMI)      *
# 4  VA 30-day Readmission Rates     Congestive Heart Failure (CHF)  19.24
#
#   95% Confidence Lower Limit 95% Confidence Upper Limit  VHA\n National Rate  \
# 0                      12.45                      18.03                15.57
# 1                      18.03                      23.92                19.34
# 2                      13.06                      19.15                14.74
# 3                          *                          *                15.57
# 4                      15.66                      23.07                19.34
#
#   Number of\n Observations Number of\n Readmissions  \
# 0                      119                       15
# 1                      409                       85
# 2                      136                       25
# 3                        4                        0
# 4                       87                       15
#
#                                         Footnotes  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3  * Rates are not reported for Observations < 25
# 4                                             NaN
#
#                       Date Range
# 0  October 2013 – September 2015
# 1  October 2013 – September 2015
# 2  October 2013 – September 2015
# 3  October 2013 – September 2015
# 4  October 2013 – September 2015

# %%
working_psi_df = main_psi_df[(main_psi_df["State"]== 'VA') |    (main_psi_df["State"]== 'GA')]
working_psi_df.head()
ga_psi_df = working_df[working_df["State"]=="GA"]
ga_psi_df.head()
va_psi_df = working_df[working_df["State"]=="VA"]
va_psi_df.head()
# Out:
#         CCN#               VHA Facility                 Address     City  \
# 1404  49006F  HAMPTON VA MEDICAL CENTER  100 EMANCIPATION DRIVE  HAMPTON
# 1405  49006F  HAMPTON VA MEDICAL CENTER  100 EMANCIPATION DRIVE  HAMPTON
# 1406  49006F  HAMPTON VA MEDICAL CENTER  100 EMANCIPATION DRIVE  HAMPTON
# 1407  49006F  HAMPTON VA MEDICAL CENTER  100 EMANCIPATION DRIVE  HAMPTON
# 1408  49006F  HAMPTON VA MEDICAL CENTER  100 EMANCIPATION DRIVE  HAMPTON
#
#      State  Zip\nCode                          Measure  \
# 1404    VA    23667.0  Patient Safety Indicators (PSI)
# 1405    VA    23667.0  Patient Safety Indicators (PSI)
# 1406    VA    23667.0  Patient Safety Indicators (PSI)
# 1407    VA    23667.0  Patient Safety Indicators (PSI)
# 1408    VA    23667.0  Patient Safety Indicators (PSI)
#
#                                  Indicator Observed Rate Expected Rate  \
# 1404                   03 - Pressure Ulcer             0          0.46
# 1405  04 - Death Among Surgical Inpatients             *             *
# 1406          06 - Iatrogenic Pneumothorax             0          0.26
# 1407                  07 - CLAB Infections             0          0.31
# 1408              08 - Postop Hip Fracture             0          0.04
#
#      Risk Adjusted Rate 95% Confidence Lower Limit 95% Confidence Upper Limit  \
# 1404                  0                          0                       1.29
# 1405                  *                          *                          *
# 1406                  0                          0                       0.61
# 1407                  0                          0                       0.44
# 1408                  0                          0                       0.75
#
#                                           Footnotes  \
# 1404                                            NaN
# 1405  *Rates are not reported for Observations < 25
# 1406                                            NaN
# 1407                                            NaN
# 1408                                            NaN
#
#                          Date Range
# 1404  October 2012 – September 2015
# 1405  October 2012 – September 2015
# 1406  October 2012 – September 2015
# 1407  October 2012 – September 2015
# 1408  October 2012 – September 2015

# %%
working_rr_df = main_rr_df[(main_rr_df["State"]== 'VA') |    (main_rr_df["State"]== 'GA')]
working_rr_df.head()
ga_rr_df = working_rr_df[working_rr_df["State"]=="GA"]
ga_rr_df.head()
va_rr_df = working_rr_df[working_rr_df["State"]=="VA"]
va_rr_df.head()
# Out:
#        CCN#                VHA Facility                    Address      City  \
# 342  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 343  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 344  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 345  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
# 346  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
#
#     State  Zip\nCode                      Measure  \
# 342    VA    23667.0  VA 30-day Readmission Rates
# 343    VA    23667.0  VA 30-day Readmission Rates
# 344    VA    23667.0  VA 30-day Readmission Rates
# 345    VA    23249.0  VA 30-day Readmission Rates
# 346    VA    23249.0  VA 30-day Readmission Rates
#
#                         Disease Cohort   Rate 95% Confidence Lower Limit  \
# 342  Acute Myocardial Infarction (AMI)      *                          *
# 343     Congestive Heart Failure (CHF)  17.89                      14.54
# 344                     Pneumonia (PN)   14.4                      11.49
# 345  Acute Myocardial Infarction (AMI)  16.49                      14.05
# 346     Congestive Heart Failure (CHF)  19.75                      17.54
#
#     95% Confidence Upper Limit  VHA\n National Rate Number of\n Observations  \
# 342                          *                15.57                        3
# 343                      21.54                19.34                      132
# 344                       17.1                14.74                       81
# 345                      19.68                15.57                      167
# 346                       22.5                19.34                      665
#
#     Number of\n Readmissions                                       Footnotes  \
# 342                        1  * Rates are not reported for Observations < 25
# 343                       18                                             NaN
# 344                       10                                             NaN
# 345                       33                                             NaN
# 346                      135                                             NaN
#
#                         Date Range
# 342  October 2013 – September 2015
# 343  October 2013 – September 2015
# 344  October 2013 – September 2015
# 345  October 2013 – September 2015
# 346  October 2013 – September 2015

# %%
# main_dr_df
working_dr_df = main_dr_df[(main_dr_df["State"]== 'VA') |    (main_dr_df["State"]== 'GA')]
working_dr_df.head()
ga_dr_df = working_dr_df[working_dr_df["State"]=="GA"]
ga_dr_df.head()
va_dr_df = working_dr_df[working_dr_df["State"]=="VA"]
va_dr_df.head()
# Out:
#        CCN#                VHA Facility                    Address      City  \
# 342  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 343  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 344  49006F   HAMPTON VA MEDICAL CENTER     100 EMANCIPATION DRIVE   HAMPTON
# 345  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
# 346  49010F  RICHMOND VA MEDICAL CENTER  1201 BROAD ROCK BOULEVARD  RICHMOND
#
#     State  Zip\nCode                Measure  \
# 342    VA    23667.0  VA 30-day Death Rates
# 343    VA    23667.0  VA 30-day Death Rates
# 344    VA    23667.0  VA 30-day Death Rates
# 345    VA    23249.0  VA 30-day Death Rates
# 346    VA    23249.0  VA 30-day Death Rates
#
#                         Disease Cohort  Rate 95% Confidence Lower Limit  \
# 342  Acute Myocardial Infarction (AMI)     *                          *
# 343     Congestive Heart Failure (CHF)  7.63                       5.16
# 344                     Pneumonia (PN)  8.94                       6.49
# 345  Acute Myocardial Infarction (AMI)  8.93                       6.65
# 346     Congestive Heart Failure (CHF)  7.84                       6.16
#
#     95% Confidence Upper Limit  VHA\n National Rate Number of\n Observations  \
# 342                          *                 9.21                       18
# 343                      10.52                 7.72                      123
# 344                      11.85                 8.64                       85
# 345                       11.8                 9.21                      148
# 346                       9.85                 7.72                      543
#
#     Number of\n Deaths                                       Footnotes  \
# 342                  1  * Rates are not reported for Observations < 25
# 343                  8                                             NaN
# 344                  8                                             NaN
# 345                 12                                             NaN
# 346                 41                                             NaN
#
#                         Date Range
# 342  October 2013 – September 2015
# 343  October 2013 – September 2015
# 344  October 2013 – September 2015
# 345  October 2013 – September 2015
# 346  October 2013 – September 2015
